# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sbn

from math import ceil

import scipy.stats as stats

import matplotlib.pyplot as plt

from pandas.plotting import scatter_matrix







import timeit
import datetime as dt

import pandasql as ps

# %%
jan = pd.read_csv('~/Desktop/capstone2/jan_scraped_temps.csv')
feb = pd.read_csv('~/Desktop/capstone2/feb_scraped_temps.csv')
march = pd.read_csv('~/Desktop/capstone2/march_scraped_temps.csv')
april = pd.read_csv('~/Desktop/capstone2/april_scraped_temps.csv')
may = pd.read_csv('~/Desktop/capstone2/may_scraped_temps.csv')
june = pd.read_csv('~/Desktop/capstone2/june_scraped_temps.csv')
july = pd.read_csv('~/Desktop/capstone2/july_scraped_temps.csv')
august = pd.read_csv('~/Desktop/capstone2/august_scraped_temps.csv')
september = pd.read_csv('~/Desktop/capstone2/september_scraped_temps.csv')
october = pd.read_csv('~/Desktop/capstone2/october_scraped_temps.csv')
november = pd.read_csv('~/Desktop/capstone2/november_scraped_temps.csv')
december = pd.read_csv('~/Desktop/capstone2/december_scraped_temps.csv')

#jan 1st & november 8th missing

# %%
month_lst = [jan, feb, march, april, may, june, july, august, september, october, november, december ]

# %%
dall_weather_2020 = pd.concat(month_lst)

# %%
dall_weather_2020['new_hour'] = dall_weather_2020[]

# %%
dall_weather_2020.cloud.value_counts()

# %%
hours = np.arange(0,24)
hours_3 = []
for i in range (365):
    
    hours_3.append(hours)
hours_3

# %%
hours_df = pd.DataFrame(hours_3)
numpy_array = hours_df.to_numpy()
hours_col= numpy_array.reshape(8760, -1)
hours_final_df = pd.DataFrame(hours_col)

# %%
hours_final_df[2:7992]

# %%
 hours2 = hours_final_df[1:7992] #8760-768

# %%
dall_weather_2020['hours'] = hours2

# %%
dall_weather_2020[:30]

# %%
dall_weather2020['new_datetime'] = dall_weather_2020['hour'].to_datetime

# %%
dall_weather_2020['New_datetime'] = pd.to_datetime(dall_weather_2020['hour'],infer_datetime_format=True)

# %%
dall_weather_2020

# %%
dallas = pd.read_csv('~/Desktop/capstone2/DALLAS_YEAR_SCRAPE.csv')

# %%
dallas.head()
# Out:
#       hour  temp   dew humidity wind_speed  pressure  precip          cloud  \
# 0  1:42 AM  39 F  37 F     93 %      9 mph  29.09 in  0.0 in  Light Drizzle
# 1  1:53 AM  39 F  37 F     93 %      8 mph  29.10 in  0.0 in  Light Drizzle
# 2  2:44 AM  38 F  36 F     93 %      8 mph  29.11 in  0.0 in  Light Drizzle
# 3  2:53 AM  37 F  35 F     93 %      8 mph  29.11 in  0.0 in  Light Drizzle
# 4  3:46 AM  37 F  34 F     89 %     10 mph  29.14 in  0.0 in         Cloudy
#
#        Date
# 0  2021-1-1
# 1  2021-1-1
# 2  2021-1-1
# 3  2021-1-1
# 4  2021-1-1

# %%
dallas
# Out:
#            hour  temp   dew humidity wind_speed  pressure  precip  \
# 0       1:42 AM  39 F  37 F     93 %      9 mph  29.09 in  0.0 in
# 1       1:53 AM  39 F  37 F     93 %      8 mph  29.10 in  0.0 in
# 2       2:44 AM  38 F  36 F     93 %      8 mph  29.11 in  0.0 in
# 3       2:53 AM  37 F  35 F     93 %      8 mph  29.11 in  0.0 in
# 4       3:46 AM  37 F  34 F     89 %     10 mph  29.14 in  0.0 in
# ...         ...   ...   ...      ...        ...       ...     ...
# 10162   9:23 PM  42 F  39 F     89 %      3 mph  29.11 in  0.1 in
# 10163   9:53 PM  41 F  38 F     89 %      9 mph  29.10 in  0.1 in
# 10164  10:53 PM  40 F  38 F     93 %      9 mph  29.12 in  0.0 in
# 10165  11:53 PM  39 F  37 F     93 %      8 mph  29.10 in  0.0 in
# 10166  12:53 AM  39 F  37 F     93 %      7 mph  29.09 in  0.0 in
#
#                cloud        Date
# 0      Light Drizzle    2021-1-1
# 1      Light Drizzle    2021-1-1
# 2      Light Drizzle    2021-1-1
# 3      Light Drizzle    2021-1-1
# ...

# %%
dallas.hour.iloc[:1]

# %%
# dallas['new_hour'] = pd.to_datetime(dallas['hour'],infer_datetime_format=True, format ='%H')
# df_total['New_datetime'] = pd.to_datetime(df_total['New_datetime'],infer_datetime_format=True, format ='%m/%d/%Y %H')

# %%
dallas['new_hour_date'] = dallas['hour'] + ' '+  dallas['Date']

# %%
# dallas['new_hour_date'] = dallas['hour'] + dallas['Date']

# pd.to_datetime(dallas['hour'],infer_datetime_format=True, format ='%H')

# %%
dallas
# Out:
#            hour  temp   dew humidity wind_speed  pressure  precip  \
# 0       1:42 AM  39 F  37 F     93 %      9 mph  29.09 in  0.0 in
# 1       1:53 AM  39 F  37 F     93 %      8 mph  29.10 in  0.0 in
# 2       2:44 AM  38 F  36 F     93 %      8 mph  29.11 in  0.0 in
# 3       2:53 AM  37 F  35 F     93 %      8 mph  29.11 in  0.0 in
# 4       3:46 AM  37 F  34 F     89 %     10 mph  29.14 in  0.0 in
# ...         ...   ...   ...      ...        ...       ...     ...
# 10162   9:23 PM  42 F  39 F     89 %      3 mph  29.11 in  0.1 in
# 10163   9:53 PM  41 F  38 F     89 %      9 mph  29.10 in  0.1 in
# 10164  10:53 PM  40 F  38 F     93 %      9 mph  29.12 in  0.0 in
# 10165  11:53 PM  39 F  37 F     93 %      8 mph  29.10 in  0.0 in
# 10166  12:53 AM  39 F  37 F     93 %      7 mph  29.09 in  0.0 in
#
#                cloud        Date        new_hour_date
# 0      Light Drizzle    2021-1-1     1:42 AM 2021-1-1
# 1      Light Drizzle    2021-1-1     1:53 AM 2021-1-1
# ...

# %%
# dallas['new_hour'] = pd.to_datetime(dallas['hour'],infer_datetime_format=True, format ='%H')

dallas['New_datetime'] = pd.to_datetime(dallas['new_hour_date'],infer_datetime_format=True, format ='%m/%d/%Y %H')

# %%
dallas
# Out:
#            hour  temp   dew humidity wind_speed  pressure  precip  \
# 0       1:42 AM  39 F  37 F     93 %      9 mph  29.09 in  0.0 in
# 1       1:53 AM  39 F  37 F     93 %      8 mph  29.10 in  0.0 in
# 2       2:44 AM  38 F  36 F     93 %      8 mph  29.11 in  0.0 in
# 3       2:53 AM  37 F  35 F     93 %      8 mph  29.11 in  0.0 in
# 4       3:46 AM  37 F  34 F     89 %     10 mph  29.14 in  0.0 in
# ...         ...   ...   ...      ...        ...       ...     ...
# 10162   9:23 PM  42 F  39 F     89 %      3 mph  29.11 in  0.1 in
# 10163   9:53 PM  41 F  38 F     89 %      9 mph  29.10 in  0.1 in
# 10164  10:53 PM  40 F  38 F     93 %      9 mph  29.12 in  0.0 in
# 10165  11:53 PM  39 F  37 F     93 %      8 mph  29.10 in  0.0 in
# 10166  12:53 AM  39 F  37 F     93 %      7 mph  29.09 in  0.0 in
#
#                cloud        Date        new_hour_date        New_datetime
# 0      Light Drizzle    2021-1-1     1:42 AM 2021-1-1 2021-01-01 01:42:00
# ...

# %%
dallas['time_rounded'] = dallas['New_datetime'].dt.round('H').dt.hour

# %%
dallas
# Out:
#            hour  temp   dew humidity wind_speed  pressure  precip  \
# 0       1:42 AM  39 F  37 F     93 %      9 mph  29.09 in  0.0 in
# 1       1:53 AM  39 F  37 F     93 %      8 mph  29.10 in  0.0 in
# 2       2:44 AM  38 F  36 F     93 %      8 mph  29.11 in  0.0 in
# 3       2:53 AM  37 F  35 F     93 %      8 mph  29.11 in  0.0 in
# 4       3:46 AM  37 F  34 F     89 %     10 mph  29.14 in  0.0 in
# ...         ...   ...   ...      ...        ...       ...     ...
# 10162   9:23 PM  42 F  39 F     89 %      3 mph  29.11 in  0.1 in
# 10163   9:53 PM  41 F  38 F     89 %      9 mph  29.10 in  0.1 in
# 10164  10:53 PM  40 F  38 F     93 %      9 mph  29.12 in  0.0 in
# 10165  11:53 PM  39 F  37 F     93 %      8 mph  29.10 in  0.0 in
# 10166  12:53 AM  39 F  37 F     93 %      7 mph  29.09 in  0.0 in
#
#                cloud        Date        new_hour_date        New_datetime  \
# 0      Light Drizzle    2021-1-1     1:42 AM 2021-1-1 2021-01-01 01:42:00
# ...

# %%
type(dallas.time_rounded[0])
dallas.time_rounded[0]
# Out:
# 2

# %%
dallas['time_rounded'] = dallas['time_rounded'].apply(str)

# %%
dallas['time_rounded2'] = dallas['Date'] + ' '+  dallas['time_rounded']

# %%
dallas
# Out:
#            hour  temp   dew humidity wind_speed  pressure  precip  \
# 0       1:42 AM  39 F  37 F     93 %      9 mph  29.09 in  0.0 in
# 1       1:53 AM  39 F  37 F     93 %      8 mph  29.10 in  0.0 in
# 2       2:44 AM  38 F  36 F     93 %      8 mph  29.11 in  0.0 in
# 3       2:53 AM  37 F  35 F     93 %      8 mph  29.11 in  0.0 in
# 4       3:46 AM  37 F  34 F     89 %     10 mph  29.14 in  0.0 in
# ...         ...   ...   ...      ...        ...       ...     ...
# 10162   9:23 PM  42 F  39 F     89 %      3 mph  29.11 in  0.1 in
# 10163   9:53 PM  41 F  38 F     89 %      9 mph  29.10 in  0.1 in
# 10164  10:53 PM  40 F  38 F     93 %      9 mph  29.12 in  0.0 in
# 10165  11:53 PM  39 F  37 F     93 %      8 mph  29.10 in  0.0 in
# 10166  12:53 AM  39 F  37 F     93 %      7 mph  29.09 in  0.0 in
#
#                cloud        Date        new_hour_date        New_datetime  \
# 0      Light Drizzle    2021-1-1     1:42 AM 2021-1-1 2021-01-01 01:42:00
# ...

# %%
dallas['New_datetime2'] = pd.to_datetime(dallas['time_rounded2'],infer_datetime_format=True,format ='%m/%d/%Y %H')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2053         try:
# -> 2054             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2055             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-24-3b51ad536cf0> in <module>
# ----> 1 dallas['New_datetime2'] = pd.to_datetime(dallas['time_rounded2'],infer_datetime_format=True,format ='%m/%d/%Y %H')
#
# ...

# %%
dallas
# Out:
#            hour  temp   dew humidity wind_speed  pressure  precip  \
# 0       1:42 AM  39 F  37 F     93 %      9 mph  29.09 in  0.0 in
# 1       1:53 AM  39 F  37 F     93 %      8 mph  29.10 in  0.0 in
# 2       2:44 AM  38 F  36 F     93 %      8 mph  29.11 in  0.0 in
# 3       2:53 AM  37 F  35 F     93 %      8 mph  29.11 in  0.0 in
# 4       3:46 AM  37 F  34 F     89 %     10 mph  29.14 in  0.0 in
# ...         ...   ...   ...      ...        ...       ...     ...
# 10162   9:23 PM  42 F  39 F     89 %      3 mph  29.11 in  0.1 in
# 10163   9:53 PM  41 F  38 F     89 %      9 mph  29.10 in  0.1 in
# 10164  10:53 PM  40 F  38 F     93 %      9 mph  29.12 in  0.0 in
# 10165  11:53 PM  39 F  37 F     93 %      8 mph  29.10 in  0.0 in
# 10166  12:53 AM  39 F  37 F     93 %      7 mph  29.09 in  0.0 in
#
#                cloud        Date        new_hour_date        New_datetime  \
# 0      Light Drizzle    2021-1-1     1:42 AM 2021-1-1 2021-01-01 01:42:00
# ...

# %%
print(type(dallas['New_datetime2'][0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
dallas['time_rounded4']= dallas['time_rounded2'].apply(lambda x:f'{x}:00:00')

# %%
dallas['New_datetime2'] = pd.to_datetime(dallas['time_rounded4'],infer_datetime_format=True,format ='%m/%d/%Y %H')

# %%
x_Test2323 = dallas['New_datetime2'][0]
print(type(x_Test2323))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
dallas
# Out:
#            hour  temp   dew humidity wind_speed  pressure  precip  \
# 0       1:42 AM  39 F  37 F     93 %      9 mph  29.09 in  0.0 in
# 1       1:53 AM  39 F  37 F     93 %      8 mph  29.10 in  0.0 in
# 2       2:44 AM  38 F  36 F     93 %      8 mph  29.11 in  0.0 in
# 3       2:53 AM  37 F  35 F     93 %      8 mph  29.11 in  0.0 in
# 4       3:46 AM  37 F  34 F     89 %     10 mph  29.14 in  0.0 in
# ...         ...   ...   ...      ...        ...       ...     ...
# 10162   9:23 PM  42 F  39 F     89 %      3 mph  29.11 in  0.1 in
# 10163   9:53 PM  41 F  38 F     89 %      9 mph  29.10 in  0.1 in
# 10164  10:53 PM  40 F  38 F     93 %      9 mph  29.12 in  0.0 in
# 10165  11:53 PM  39 F  37 F     93 %      8 mph  29.10 in  0.0 in
# 10166  12:53 AM  39 F  37 F     93 %      7 mph  29.09 in  0.0 in
#
#                cloud        Date        new_hour_date        New_datetime  \
# 0      Light Drizzle    2021-1-1     1:42 AM 2021-1-1 2021-01-01 01:42:00
# ...

# %%
dallas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10167 entries, 0 to 10166
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   hour           10167 non-null  object
#  1   temp           10167 non-null  object
#  2   dew            10167 non-null  object
#  3   humidity       10167 non-null  object
#  4   wind_speed     10167 non-null  object
#  5   pressure       10167 non-null  object
#  6   precip         10167 non-null  object
#  7   cloud          10165 non-null  object
#  8   Date           10167 non-null  object
#  9   new_hour_date  10167 non-null  object
#  10  New_datetime   10167 non-null  datetime64[ns]
#  11  time_rounded   10167 non-null  object
#  12  time_rounded2  10167 non-null  object
#  13  New_datetime2  10167 non-null  datetime64[ns]
#  14  time_rounded3  10167 non-null  object
#  15  time_rounded4  10167 non-null  object
# dtypes: datetime64[ns](2), object(14)
# ...

# %%
del dallas['hour']
del dallas['Date']
del dallas['new_hour_date']
del dallas['New_datetime']
del dallas['time_rounded']
del dallas['time_rounded2']
del dallas['time_rounded3']
del dallas['time_rounded4']
# del df_dallas['hour']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hour'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-3057f64ce19b> in <module>
# ----> 1 del dallas['hour']
# ...

# %%
dallas
# Out:
#        temp   dew humidity wind_speed  pressure  precip          cloud  \
# 0      39 F  37 F     93 %      9 mph  29.09 in  0.0 in  Light Drizzle
# 1      39 F  37 F     93 %      8 mph  29.10 in  0.0 in  Light Drizzle
# 2      38 F  36 F     93 %      8 mph  29.11 in  0.0 in  Light Drizzle
# 3      37 F  35 F     93 %      8 mph  29.11 in  0.0 in  Light Drizzle
# 4      37 F  34 F     89 %     10 mph  29.14 in  0.0 in         Cloudy
# ...     ...   ...      ...        ...       ...     ...            ...
# 10162  42 F  39 F     89 %      3 mph  29.11 in  0.1 in     Light Rain
# 10163  41 F  38 F     89 %      9 mph  29.10 in  0.1 in     Light Rain
# 10164  40 F  38 F     93 %      9 mph  29.12 in  0.0 in  Light Drizzle
# 10165  39 F  37 F     93 %      8 mph  29.10 in  0.0 in  Light Drizzle
# 10166  39 F  37 F     93 %      7 mph  29.09 in  0.0 in  Light Drizzle
#
#             New_datetime2        time_rounded4
# 0     2021-01-01 02:00:00     2021-1-1 2:00:00
# ...

# %%
dallas['New_datetime']= dallas['time_rounded4']

# %%
dallas
# Out:
#        temp   dew humidity wind_speed  pressure  precip          cloud  \
# 0      39 F  37 F     93 %      9 mph  29.09 in  0.0 in  Light Drizzle
# 1      39 F  37 F     93 %      8 mph  29.10 in  0.0 in  Light Drizzle
# 2      38 F  36 F     93 %      8 mph  29.11 in  0.0 in  Light Drizzle
# 3      37 F  35 F     93 %      8 mph  29.11 in  0.0 in  Light Drizzle
# 4      37 F  34 F     89 %     10 mph  29.14 in  0.0 in         Cloudy
# ...     ...   ...      ...        ...       ...     ...            ...
# 10162  42 F  39 F     89 %      3 mph  29.11 in  0.1 in     Light Rain
# 10163  41 F  38 F     89 %      9 mph  29.10 in  0.1 in     Light Rain
# 10164  40 F  38 F     93 %      9 mph  29.12 in  0.0 in  Light Drizzle
# 10165  39 F  37 F     93 %      8 mph  29.10 in  0.0 in  Light Drizzle
# 10166  39 F  37 F     93 %      7 mph  29.09 in  0.0 in  Light Drizzle
#
#             New_datetime2        time_rounded4         New_datetime
# ...

# %%
dallas['New_datetime'] = pd.to_datetime(dallas['New_datetime'],infer_datetime_format=True,format ='%m/%d/%Y %H')

# %%
dallas.to_csv (r'/Users/cp/Desktop/capstone2/DALLASV1_FINAL_WEATHER.csv', index = False, header=True)

# %%
dallas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10167 entries, 0 to 10166
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   temp           10167 non-null  object
#  1   dew            10167 non-null  object
#  2   humidity       10167 non-null  object
#  3   wind_speed     10167 non-null  object
#  4   pressure       10167 non-null  object
#  5   precip         10167 non-null  object
#  6   cloud          10165 non-null  object
#  7   New_datetime2  10167 non-null  datetime64[ns]
#  8   time_rounded4  10167 non-null  object
#  9   New_datetime   10167 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), object(8)
# memory usage: 794.4+ KB
