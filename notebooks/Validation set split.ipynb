# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('/Users/cp/Documents/dsi/capstone2/capstone2/data/validation_set.csv')

# %%
df.shape
# Out:
# (200, 490)

# %%
y = df.pop('death_from_cancer')
X = df

# %%
X.to_csv(r'../data/validation_X_set.csv', index = False)

# %%
y.to_csv(r'../data/validation_y_set.csv', index = False)

# %%
df.shape
# Out:
# (200, 489)

# %%
df
# Out:
#       brca1   brca2   palb2    pten    tp53     atm    cdh1   chek2     nbn  \
# 0    1.5168 -1.8925 -0.7698  1.5281  2.2336 -0.0505  0.4120  0.2913 -1.7848
# 1   -0.0134  0.6644 -0.5336  0.5190  0.1878 -1.3654 -0.0335 -1.0429  0.8029
# 2   -0.0616  0.1084 -0.6249  0.2310  0.0583 -0.1163  1.4386 -0.1129  1.4486
# 3   -0.4585  1.0126  1.8303 -1.1746 -0.6703 -0.5445 -0.4007  2.2545 -1.2164
# 4    0.4022 -1.5537 -0.7546 -0.0122 -0.9086  0.0591  0.5064 -0.3064 -1.0644
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 195  0.7091 -0.7204  0.1777 -0.8531 -1.4953  0.7484 -0.8120  1.8439  1.4438
# 196 -0.1773  0.4206 -1.1537  1.0093  0.1084 -0.2946  0.4446 -0.9303  0.0494
# 197 -0.1862  0.5544 -1.3670  0.0632  0.1578  1.2164 -0.4610 -1.0280  0.1775
# 198  2.2526  0.2393 -0.8946 -5.2623  3.5619 -1.7752  0.5062  2.5999 -0.5341
# 199  0.0528  0.5678 -0.5929  0.5640 -0.6304  0.8019 -2.5517 -1.1546 -0.7987
#
# ...
