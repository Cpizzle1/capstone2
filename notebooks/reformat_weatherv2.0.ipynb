# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sbn
from math import ceil
import scipy.stats as stats
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import timeit
import datetime as dt
import pandasql as ps

# %%
dallas = pd.read_csv('~/Desktop/Dallas_YEAR_SCRAPE.csv')

# %%
dallas['new_hour_date'] = dallas['hour'] + ' '+  dallas['Date']

# %%
dallas['New_datetime'] = pd.to_datetime(dallas['new_hour_date'],infer_datetime_format=True, format ='%m/%d/%Y %H')

# %%
dallas['time_rounded'] = dallas['New_datetime'].dt.round('H').dt.hour

# %%
dallas['time_rounded'] = dallas['time_rounded'].apply(str)

# %%
dallas['time_rounded2'] = dallas['Date'] + ' '+  dallas['time_rounded']

# %%
dallas['time_rounded4']= dallas['time_rounded2'].apply(lambda x:f'{x}:00:00')

# %%
dallas['New_datetime2'] = pd.to_datetime(dallas['time_rounded4'],infer_datetime_format=True,format ='%m/%d/%Y %H')

# %%
del dallas['hour']
del dallas['Date']
del dallas['new_hour_date']
del dallas['New_datetime']
del dallas['time_rounded']
del dallas['time_rounded2']
# del dallas['time_rounded3']
del dallas['time_rounded4']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time_rounded3'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-0ca942ddebe7> in <module>
#       5 del dallas['time_rounded']
#       6 del dallas['time_rounded2']
# ----> 7 del dallas['time_rounded3']
#       8 del dallas['time_rounded4']
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __delitem__(self, key)
#    3709             # there was no match, this call should raise the appropriate
#    3710             # exception:
# -> 3711             loc = self.axes[-1].get_loc(key)
#    3712             self._mgr.idelete(loc)
#    3713
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'time_rounded3'

# %%
dallas['New_datetime']= dallas['time_rounded4']

# %%
dallas['New_datetime'] = pd.to_datetime(dallas['New_datetime'],infer_datetime_format=True,format ='%m/%d/%Y %H')

# %%
dallas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10300 entries, 0 to 10299
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   temp           10300 non-null  object
#  1   dew            10300 non-null  object
#  2   humidity       10300 non-null  object
#  3   wind_speed     10300 non-null  object
#  4   pressure       10300 non-null  object
#  5   precip         10300 non-null  object
#  6   cloud          10299 non-null  object
#  7   time_rounded4  10300 non-null  object
#  8   New_datetime2  10300 non-null  datetime64[ns]
#  9   New_datetime   10300 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), object(8)
# memory usage: 804.8+ KB

# %%
dallas
# Out:
#        temp   dew humidity wind_speed  pressure  precip          cloud  \
# 0      45 F  25 F     46 %      0 mph  29.59 in  0.0 in         Cloudy
# 1      46 F  23 F     40 %      0 mph  29.58 in  0.0 in         Cloudy
# 2      46 F  23 F     40 %      7 mph  29.56 in  0.0 in         Cloudy
# 3      47 F  22 F     37 %      6 mph  29.55 in  0.0 in         Cloudy
# 4      47 F  23 F     39 %      6 mph  29.53 in  0.0 in         Cloudy
# ...     ...   ...      ...        ...       ...     ...            ...
# 10295  42 F  39 F     89 %      3 mph  29.11 in  0.1 in     Light Rain
# 10296  41 F  38 F     89 %      9 mph  29.10 in  0.1 in     Light Rain
# 10297  40 F  38 F     93 %      9 mph  29.12 in  0.0 in  Light Drizzle
# 10298  39 F  37 F     93 %      8 mph  29.10 in  0.0 in  Light Drizzle
# 10299  39 F  37 F     93 %      7 mph  29.09 in  0.0 in  Light Drizzle
#
#              time_rounded4       New_datetime2        New_datetime
# 0         2020-1-1 1:00:00 2020-01-01 01:00:00 2020-01-01 01:00:00
# 1         2020-1-1 2:00:00 2020-01-01 02:00:00 2020-01-01 02:00:00
# 2         2020-1-1 3:00:00 2020-01-01 03:00:00 2020-01-01 03:00:00
# 3         2020-1-1 4:00:00 2020-01-01 04:00:00 2020-01-01 04:00:00
# 4         2020-1-1 5:00:00 2020-01-01 05:00:00 2020-01-01 05:00:00
# ...                    ...                 ...                 ...
# 10295  2020-12-31 21:00:00 2020-12-31 21:00:00 2020-12-31 21:00:00
# 10296  2020-12-31 22:00:00 2020-12-31 22:00:00 2020-12-31 22:00:00
# 10297  2020-12-31 23:00:00 2020-12-31 23:00:00 2020-12-31 23:00:00
# 10298   2020-12-31 0:00:00 2020-12-31 00:00:00 2020-12-31 00:00:00
# 10299   2020-12-31 1:00:00 2020-12-31 01:00:00 2020-12-31 01:00:00
#
# [10300 rows x 10 columns]

# %%
dallas.to_csv (r'/Users/cp/Desktop/capstone2/DALLASV2_FINAL_WEATHER.csv', index = False, header=True)
